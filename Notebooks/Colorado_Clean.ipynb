# %%
import pandas as pd

# %%
results_csv = "2020Results.csv"

results_df = pd.read_csv(results_csv)

results_df.head(10)
# Out:
#         Office/Ballot Issue             Party      County  \
# 0  President/Vice President  Democratic Party       ADAMS
# 1  President/Vice President  Democratic Party     ALAMOSA
# 2  President/Vice President  Democratic Party    ARAPAHOE
# 3  President/Vice President  Democratic Party   ARCHULETA
# 4  President/Vice President  Democratic Party        BACA
# 5  President/Vice President  Democratic Party        BENT
# 6  President/Vice President  Democratic Party     BOULDER
# 7  President/Vice President  Democratic Party  BROOMFIELD
# 8  President/Vice President  Democratic Party     CHAFFEE
# 9  President/Vice President  Democratic Party    CHEYENNE
#
#    Candidate/Judge/Ballot Issue Title Yes Votes/Percentage No Votes/Percentage
# 0  Joseph R. Biden / Kamala D. Harris              134,202                 NaN
# 1  Joseph R. Biden / Kamala D. Harris                3,759                 NaN
# 2  Joseph R. Biden / Kamala D. Harris              213,607                 NaN
# ...

# %% [markdown]
# ## Clean Dem Presidential Results

# %%
dem_party = results_df.loc[results_df['Party'] == 'Democratic Party']
dem_party
# Out:
#                   Office/Ballot Issue             Party     County  \
# 0            President/Vice President  Democratic Party      ADAMS
# 1            President/Vice President  Democratic Party    ALAMOSA
# 2            President/Vice President  Democratic Party   ARAPAHOE
# 3            President/Vice President  Democratic Party  ARCHULETA
# 4            President/Vice President  Democratic Party       BACA
# ...                               ...               ...        ...
# 3472  District Attorney - District 18  Democratic Party        NaN
# 3473  District Attorney - District 18  Democratic Party        NaN
# 3483  District Attorney - District 20  Democratic Party    BOULDER
# 3484  District Attorney - District 20  Democratic Party        NaN
# 3485  District Attorney - District 20  Democratic Party        NaN
#
#       Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 0     Joseph R. Biden / Kamala D. Harris              134,202
# ...

# %%
dem_presidential = dem_party.loc[dem_party['Office/Ballot Issue'] == 'President/Vice President']
dem_presidential
# Out:
#          Office/Ballot Issue             Party      County  \
# 0   President/Vice President  Democratic Party       ADAMS
# 1   President/Vice President  Democratic Party     ALAMOSA
# 2   President/Vice President  Democratic Party    ARAPAHOE
# 3   President/Vice President  Democratic Party   ARCHULETA
# 4   President/Vice President  Democratic Party        BACA
# ..                       ...               ...         ...
# 61  President/Vice President  Democratic Party  WASHINGTON
# 62  President/Vice President  Democratic Party        WELD
# 63  President/Vice President  Democratic Party        YUMA
# 64  President/Vice President  Democratic Party         NaN
# 65  President/Vice President  Democratic Party         NaN
#
#                    Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 0                  Joseph R. Biden / Kamala D. Harris              134,202
# 1                  Joseph R. Biden / Kamala D. Harris                3,759
# ...

# %%
total_dem_pres = dem_presidential.iloc[[64, 65]]
total_dem_pres
# Out:
#          Office/Ballot Issue             Party County  \
# 64  President/Vice President  Democratic Party    NaN
# 65  President/Vice President  Democratic Party    NaN
#
#                    Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 64     Joseph R. Biden / Kamala D. Harris Total Votes            1,804,352
# 65  Joseph R. Biden / Kamala D. Harris Vote % (WIN...               55.40%
#
#    No Votes/Percentage
# 64                 NaN
# 65                 NaN

# %%
dem_counties = dem_presidential[0:64]
dem_counties
# Out:
#          Office/Ballot Issue             Party      County  \
# 0   President/Vice President  Democratic Party       ADAMS
# 1   President/Vice President  Democratic Party     ALAMOSA
# 2   President/Vice President  Democratic Party    ARAPAHOE
# 3   President/Vice President  Democratic Party   ARCHULETA
# 4   President/Vice President  Democratic Party        BACA
# ..                       ...               ...         ...
# 59  President/Vice President  Democratic Party      SUMMIT
# 60  President/Vice President  Democratic Party      TELLER
# 61  President/Vice President  Democratic Party  WASHINGTON
# 62  President/Vice President  Democratic Party        WELD
# 63  President/Vice President  Democratic Party        YUMA
#
#     Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 0   Joseph R. Biden / Kamala D. Harris              134,202
# 1   Joseph R. Biden / Kamala D. Harris                3,759
# 2   Joseph R. Biden / Kamala D. Harris              213,607
# ...

# %%
dem_counties.to_csv('DemCountyResults.csv')

# %% [markdown]
# ## Clean Rep Presidential Results

# %%
rep_party = results_df.loc[results_df['Party'] == 'Republican Party']
rep_party
# Out:
#                   Office/Ballot Issue             Party     County  \
# 66           President/Vice President  Republican Party      ADAMS
# 67           President/Vice President  Republican Party    ALAMOSA
# 68           President/Vice President  Republican Party   ARAPAHOE
# 69           President/Vice President  Republican Party  ARCHULETA
# 70           President/Vice President  Republican Party       BACA
# ...                               ...               ...        ...
# 3488  District Attorney - District 21  Republican Party        NaN
# 3489  District Attorney - District 22  Republican Party    DOLORES
# 3490  District Attorney - District 22  Republican Party  MONTEZUMA
# 3491  District Attorney - District 22  Republican Party        NaN
# 3492  District Attorney - District 22  Republican Party        NaN
#
#             Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 66          Donald J. Trump / Michael R. Pence               95,657
# ...

# %%
rep_presidential = rep_party.loc[rep_party['Office/Ballot Issue'] == 'President/Vice President']
rep_presidential
# Out:
#           Office/Ballot Issue             Party      County  \
# 66   President/Vice President  Republican Party       ADAMS
# 67   President/Vice President  Republican Party     ALAMOSA
# 68   President/Vice President  Republican Party    ARAPAHOE
# 69   President/Vice President  Republican Party   ARCHULETA
# 70   President/Vice President  Republican Party        BACA
# ..                        ...               ...         ...
# 127  President/Vice President  Republican Party  WASHINGTON
# 128  President/Vice President  Republican Party        WELD
# 129  President/Vice President  Republican Party        YUMA
# 130  President/Vice President  Republican Party         NaN
# 131  President/Vice President  Republican Party         NaN
#
#                  Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 66               Donald J. Trump / Michael R. Pence               95,657
# 67               Donald J. Trump / Michael R. Pence                3,813
# ...

# %%
total_rep_pres = rep_presidential.iloc[[64, 65]]
total_rep_pres
# Out:
#           Office/Ballot Issue             Party County  \
# 130  President/Vice President  Republican Party    NaN
# 131  President/Vice President  Republican Party    NaN
#
#                  Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 130  Donald J. Trump / Michael R. Pence Total Votes            1,364,607
# 131       Donald J. Trump / Michael R. Pence Vote %               41.90%
#
#     No Votes/Percentage
# 130                 NaN
# 131                 NaN

# %%
rep_counties = rep_presidential[0:64]
rep_counties
# Out:
#           Office/Ballot Issue             Party      County  \
# 66   President/Vice President  Republican Party       ADAMS
# 67   President/Vice President  Republican Party     ALAMOSA
# 68   President/Vice President  Republican Party    ARAPAHOE
# 69   President/Vice President  Republican Party   ARCHULETA
# 70   President/Vice President  Republican Party        BACA
# ..                        ...               ...         ...
# 125  President/Vice President  Republican Party      SUMMIT
# 126  President/Vice President  Republican Party      TELLER
# 127  President/Vice President  Republican Party  WASHINGTON
# 128  President/Vice President  Republican Party        WELD
# 129  President/Vice President  Republican Party        YUMA
#
#      Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 66   Donald J. Trump / Michael R. Pence               95,657
# 67   Donald J. Trump / Michael R. Pence                3,813
# ...

# %%
rep_counties.to_csv('RepCountyResults.csv')

# %% [markdown]
# ## County Combined Results

# %%
county_names = results_df['County'].unique()
county_names
# Out:
# array(['ADAMS', 'ALAMOSA', 'ARAPAHOE', 'ARCHULETA', 'BACA', 'BENT',
#        'BOULDER', 'BROOMFIELD', 'CHAFFEE', 'CHEYENNE', 'CLEAR CREEK',
#        'CONEJOS', 'COSTILLA', 'CROWLEY', 'CUSTER', 'DELTA', 'DENVER',
#        'DOLORES', 'DOUGLAS', 'EAGLE', 'ELBERT', 'EL PASO', 'FREMONT',
#        'GARFIELD', 'GILPIN', 'GRAND', 'GUNNISON', 'HINSDALE', 'HUERFANO',
#        'JACKSON', 'JEFFERSON', 'KIOWA', 'KIT CARSON', 'LAKE', 'LA PLATA',
#        'LARIMER', 'LAS ANIMAS', 'LINCOLN', 'LOGAN', 'MESA', 'MINERAL',
#        'MOFFAT', 'MONTEZUMA', 'MONTROSE', 'MORGAN', 'OTERO', 'OURAY',
#        'PARK', 'PHILLIPS', 'PITKIN', 'PROWERS', 'PUEBLO', 'RIO BLANCO',
#        'RIO GRANDE', 'ROUTT', 'SAGUACHE', 'SAN JUAN', 'SAN MIGUEL',
#        'SEDGWICK', 'SUMMIT', 'TELLER', 'WASHINGTON', 'WELD', 'YUMA', nan],
#       dtype=object)

# %%
total_presidential = results_df.loc[results_df['Office/Ballot Issue'] == 'President/Vice President']
total_presidential
# Out:
#            Office/Ballot Issue                                Party  \
# 0     President/Vice President                     Democratic Party
# 1     President/Vice President                     Democratic Party
# 2     President/Vice President                     Democratic Party
# 3     President/Vice President                     Democratic Party
# 4     President/Vice President                     Democratic Party
# ...                        ...                                  ...
# 1579  President/Vice President  Unaffiliated / No Party Affiliation
# 1580  President/Vice President  Unaffiliated / No Party Affiliation
# 1581  President/Vice President  Unaffiliated / No Party Affiliation
# 1582  President/Vice President  Unaffiliated / No Party Affiliation
# 1583  President/Vice President  Unaffiliated / No Party Affiliation
#
#           County     Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# ...

# %%
adams = total_presidential.loc[total_presidential['County']== 'ADAMS']


alamose = total_presidential.loc[total_presidential['County']== 'ALAMOSA']

arapahoe = total_presidential.loc[total_presidential['County']== 'ARAPAHOE']
archuleta = total_presidential.loc[total_presidential['County']== 'ARCHULETA']
baca = total_presidential.loc[total_presidential['County']== 'BACA']
bent = total_presidential.loc[total_presidential['County']== 'BENT']

boulder = total_presidential.loc[total_presidential['County']== 'BOULDER']
broomfield = total_presidential.loc[total_presidential['County']== 'BROOMFIELD']
chaffee = total_presidential.loc[total_presidential['County']== 'CHAFFEE']
cheyenne = total_presidential.loc[total_presidential['County']== 'CHEYENNE']

# %%
clearcreek = total_presidential.loc[total_presidential['County']== 'CLEAR CREEK']
conejos = total_presidential.loc[total_presidential['County']== 'CONEJOS']
costilla = total_presidential.loc[total_presidential['County']== 'COSTILLA']
crowley = total_presidential.loc[total_presidential['County']== 'CROWLEY']

custer = total_presidential.loc[total_presidential['County']== 'CUSTER']
delta = total_presidential.loc[total_presidential['County']== 'DELTA']
denver = total_presidential.loc[total_presidential['County']== 'DENVER']
dolores = total_presidential.loc[total_presidential['County']== 'DOLORES']

douglas = total_presidential.loc[total_presidential['County']== 'DOUGLAS']
eagle = total_presidential.loc[total_presidential['County']== 'EAGLE']
elbert = total_presidential.loc[total_presidential['County']== 'ELBERT']
elpaso = total_presidential.loc[total_presidential['County']== 'EL PASO']

fremont = total_presidential.loc[total_presidential['County']== 'FREMONT']
garfield = total_presidential.loc[total_presidential['County']== 'GARFIELD']
giplin = total_presidential.loc[total_presidential['County']== 'GILPIN']
grand = total_presidential.loc[total_presidential['County']== 'GRAND']

gunnison = total_presidential.loc[total_presidential['County']== 'GUNNISON']
hinsdale = total_presidential.loc[total_presidential['County']== 'HINSDALE']
huerfano = total_presidential.loc[total_presidential['County']== 'HUERFANO']

# %%
    
jackson = total_presidential.loc[total_presidential['County']== 'JACKSON']
jefferson = total_presidential.loc[total_presidential['County']== 'JEFFERSON']
kiowa = total_presidential.loc[total_presidential['County']== 'KIOWA']
kitcarson = total_presidential.loc[total_presidential['County']== 'KIT CARSON']

lake = total_presidential.loc[total_presidential['County']== 'LAKE']
laplata = total_presidential.loc[total_presidential['County']== 'LA PLATA']
larimer = total_presidential.loc[total_presidential['County']== 'LARIMER']

lasanimas = total_presidential.loc[total_presidential['County']== 'LAS ANIMAS']
lincoln = total_presidential.loc[total_presidential['County']== 'LINCOLN']
logan = total_presidential.loc[total_presidential['County']== 'LOGAN']
mesa = total_presidential.loc[total_presidential['County']== 'MESA']

mineral = total_presidential.loc[total_presidential['County']== 'MINERAL']
moffat = total_presidential.loc[total_presidential['County']== 'MOFFAT']
montezuma = total_presidential.loc[total_presidential['County']== 'MONTEZUMA']

##
montrose = total_presidential.loc[total_presidential['County']== 'MONTROSE']
morgan = total_presidential.loc[total_presidential['County']== 'MORGAN']
otero = total_presidential.loc[total_presidential['County']== 'OTERO']
ouray = total_presidential.loc[total_presidential['County']== 'OURAY']

park = total_presidential.loc[total_presidential['County']== 'PARK']
phillips = total_presidential.loc[total_presidential['County']== 'PHILLIPS']
pitkin = total_presidential.loc[total_presidential['County']== 'PITKIN']
##

        
prowers = total_presidential.loc[total_presidential['County']== 'PROWERS']
pueblo = total_presidential.loc[total_presidential['County']== 'PUEBLO']
rioblanco = total_presidential.loc[total_presidential['County']== 'RIO BLANCO']
riogrande = total_presidential.loc[total_presidential['County']== 'RIO GRANDE']

routt = total_presidential.loc[total_presidential['County']== 'ROUTT']
saguache = total_presidential.loc[total_presidential['County']== 'SAGUACHE']
sanjaun = total_presidential.loc[total_presidential['County']== 'SAN JUAN']

##
sanmiguel = total_presidential.loc[total_presidential['County']== 'SAN MIGUEL']
sedgwick = total_presidential.loc[total_presidential['County']== 'SEDGWICK']
summit = total_presidential.loc[total_presidential['County']== 'SUMMIT']

teller = total_presidential.loc[total_presidential['County']== 'TELLER']
washington = total_presidential.loc[total_presidential['County']== 'WASHINGTON']
weld = total_presidential.loc[total_presidential['County']== 'WELD']

yuma = total_presidential.loc[total_presidential['County']== 'YUMA']
yuma
# Out:
#            Office/Ballot Issue                                Party County  \
# 63    President/Vice President                     Democratic Party   YUMA
# 129   President/Vice President                     Republican Party   YUMA
# 195   President/Vice President          American Constitution Party   YUMA
# 261   President/Vice President              Unity Party of Colorado   YUMA
# 327   President/Vice President                          Green Party   YUMA
# 393   President/Vice President                Approval Voting Party   YUMA
# 459   President/Vice President                    Libertarian Party   YUMA
# 525   President/Vice President            American Solidarity Party   YUMA
# 591   President/Vice President                         Unaffiliated   YUMA
# 657   President/Vice President                    Prohibition Party   YUMA
# 723   President/Vice President                       Alliance Party   YUMA
# ...

# %%
yuma.set_index(['County'])
weld.set_index(['County'])
# Out:
#              Office/Ballot Issue                                Party  \
# County
# WELD    President/Vice President                     Democratic Party
# WELD    President/Vice President                     Republican Party
# WELD    President/Vice President          American Constitution Party
# WELD    President/Vice President              Unity Party of Colorado
# WELD    President/Vice President                          Green Party
# WELD    President/Vice President                Approval Voting Party
# WELD    President/Vice President                    Libertarian Party
# WELD    President/Vice President            American Solidarity Party
# WELD    President/Vice President                         Unaffiliated
# WELD    President/Vice President                    Prohibition Party
# WELD    President/Vice President                       Alliance Party
# WELD    President/Vice President                    Progressive Party
# ...

# %%
county_df = pd.DataFrame({"Yuma": yuma, "Weld": weld})
county_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3176798192ef> in <module>
# ----> 1 county_df = pd.DataFrame({"Yuma": yuma, "Weld": weld})
#       2 county_df
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# ...
