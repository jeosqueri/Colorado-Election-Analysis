# %%
import pandas as pd

# %%
results_csv = "2020Results.csv"

results_df = pd.read_csv(results_csv)

results_df.head(10)
# Out:
#         Office/Ballot Issue             Party      County  \
# 0  President/Vice President  Democratic Party       ADAMS
# 1  President/Vice President  Democratic Party     ALAMOSA
# 2  President/Vice President  Democratic Party    ARAPAHOE
# 3  President/Vice President  Democratic Party   ARCHULETA
# 4  President/Vice President  Democratic Party        BACA
# 5  President/Vice President  Democratic Party        BENT
# 6  President/Vice President  Democratic Party     BOULDER
# 7  President/Vice President  Democratic Party  BROOMFIELD
# 8  President/Vice President  Democratic Party     CHAFFEE
# 9  President/Vice President  Democratic Party    CHEYENNE
#
#    Candidate/Judge/Ballot Issue Title Yes Votes/Percentage No Votes/Percentage
# 0  Joseph R. Biden / Kamala D. Harris              134,202                 NaN
# 1  Joseph R. Biden / Kamala D. Harris                3,759                 NaN
# 2  Joseph R. Biden / Kamala D. Harris              213,607                 NaN
# ...

# %% [markdown]
# ## Clean Dem Presidential Results

# %%
results_df['Party'].unique()
# Out:
# array(['Democratic Party', 'Republican Party',
#        'American Constitution Party', 'Unity Party of Colorado',
#        'Green Party', 'Approval Voting Party', 'Libertarian Party',
#        'American Solidarity Party', 'Unaffiliated', 'Prohibition Party',
#        'Alliance Party', 'Progressive Party', 'Socialist Workers Party',
#        'Socialist Equality Party', 'Independent American Party',
#        'Socialism and Liberation', 'No Party Affiliation', 'Independent',
#        'Unaffiliated / No Party Affiliation', nan], dtype=object)

# %%
third_party = results_df.loc[results_df['Party'] != 'Democratic Party']
third_party
# Out:
#               Office/Ballot Issue             Party      County  \
# 66       President/Vice President  Republican Party       ADAMS
# 67       President/Vice President  Republican Party     ALAMOSA
# 68       President/Vice President  Republican Party    ARAPAHOE
# 69       President/Vice President  Republican Party   ARCHULETA
# 70       President/Vice President  Republican Party        BACA
# ...                           ...               ...         ...
# 4909  Proposition 118 (STATUTORY)               NaN  WASHINGTON
# 4910  Proposition 118 (STATUTORY)               NaN        WELD
# 4911  Proposition 118 (STATUTORY)               NaN        YUMA
# 4912  Proposition 118 (STATUTORY)               NaN         NaN
# 4913  Proposition 118 (STATUTORY)               NaN         NaN
#
#                      Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 66                   Donald J. Trump / Michael R. Pence               95,657
# ...

# %%
third_party = third_party.loc[third_party['Party'] != 'Republican Party']
third_party
# Out:
#               Office/Ballot Issue                        Party      County  \
# 132      President/Vice President  American Constitution Party       ADAMS
# 133      President/Vice President  American Constitution Party     ALAMOSA
# 134      President/Vice President  American Constitution Party    ARAPAHOE
# 135      President/Vice President  American Constitution Party   ARCHULETA
# 136      President/Vice President  American Constitution Party        BACA
# ...                           ...                          ...         ...
# 4909  Proposition 118 (STATUTORY)                          NaN  WASHINGTON
# 4910  Proposition 118 (STATUTORY)                          NaN        WELD
# 4911  Proposition 118 (STATUTORY)                          NaN        YUMA
# 4912  Proposition 118 (STATUTORY)                          NaN         NaN
# 4913  Proposition 118 (STATUTORY)                          NaN         NaN
#
# ...

# %%
third_party_pres = third_party.loc[third_party['Office/Ballot Issue'] == 'President/Vice President']
third_party_pres
# Out:
#            Office/Ballot Issue                                Party  \
# 132   President/Vice President          American Constitution Party
# 133   President/Vice President          American Constitution Party
# 134   President/Vice President          American Constitution Party
# 135   President/Vice President          American Constitution Party
# 136   President/Vice President          American Constitution Party
# ...                        ...                                  ...
# 1579  President/Vice President  Unaffiliated / No Party Affiliation
# 1580  President/Vice President  Unaffiliated / No Party Affiliation
# 1581  President/Vice President  Unaffiliated / No Party Affiliation
# 1582  President/Vice President  Unaffiliated / No Party Affiliation
# 1583  President/Vice President  Unaffiliated / No Party Affiliation
#
#           County     Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# ...

# %%
third_party_pres.to_csv('ThirdPartyResults2020.csv')

# %%
counties_tp = third_party_pres.groupby('County')
counties_tp




#counties_votes = counties_tp['Yes Votes/Percentage'].astype(int)
#counties_votes

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-61e8a6dca4f8> in <module>
# ----> 1 counties_df = counties_tp.to_frame()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_frame'

# %%
third_party_pres['Party'].unique()
# Out:
# array(['American Constitution Party', 'Unity Party of Colorado',
#        'Green Party', 'Approval Voting Party', 'Libertarian Party',
#        'American Solidarity Party', 'Unaffiliated', 'Prohibition Party',
#        'Alliance Party', 'Progressive Party', 'Socialist Workers Party',
#        'Socialist Equality Party', 'Independent American Party',
#        'Socialism and Liberation', 'No Party Affiliation', 'Independent',
#        'Unaffiliated / No Party Affiliation'], dtype=object)

# %% [markdown]
# ## ACP

# %%
acp = third_party_pres.loc[third_party_pres['Party'] == 'American Constitution Party']
acp
# Out:
#           Office/Ballot Issue                        Party      County  \
# 132  President/Vice President  American Constitution Party       ADAMS
# 133  President/Vice President  American Constitution Party     ALAMOSA
# 134  President/Vice President  American Constitution Party    ARAPAHOE
# 135  President/Vice President  American Constitution Party   ARCHULETA
# 136  President/Vice President  American Constitution Party        BACA
# ..                        ...                          ...         ...
# 193  President/Vice President  American Constitution Party  WASHINGTON
# 194  President/Vice President  American Constitution Party        WELD
# 195  President/Vice President  American Constitution Party        YUMA
# 196  President/Vice President  American Constitution Party         NaN
# 197  President/Vice President  American Constitution Party         NaN
#
#              Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# ...

# %%
total_acp = acp.iloc[[64,65]]
total_acp
# Out:
#           Office/Ballot Issue                        Party County  \
# 196  President/Vice President  American Constitution Party    NaN
# 197  President/Vice President  American Constitution Party    NaN
#
#              Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 196  Don Blankenship / William Mohr Total Votes                5,061
# 197       Don Blankenship / William Mohr Vote %                0.16%
#
#     No Votes/Percentage
# 196                 NaN
# 197                 NaN

# %%
acp_clean = acp[0:64]
acp_clean
# Out:
#           Office/Ballot Issue                        Party      County  \
# 132  President/Vice President  American Constitution Party       ADAMS
# 133  President/Vice President  American Constitution Party     ALAMOSA
# 134  President/Vice President  American Constitution Party    ARAPAHOE
# 135  President/Vice President  American Constitution Party   ARCHULETA
# 136  President/Vice President  American Constitution Party        BACA
# ..                        ...                          ...         ...
# 191  President/Vice President  American Constitution Party      SUMMIT
# 192  President/Vice President  American Constitution Party      TELLER
# 193  President/Vice President  American Constitution Party  WASHINGTON
# 194  President/Vice President  American Constitution Party        WELD
# 195  President/Vice President  American Constitution Party        YUMA
#
#     Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# ...

# %%
acp_clean.to_csv('ACPClean.csv')

# %% [markdown]
# ## UP

# %%
upc = third_party_pres.loc[third_party_pres['Party'] == 'Unity Party of Colorado']
upc
# Out:
#           Office/Ballot Issue                    Party      County  \
# 198  President/Vice President  Unity Party of Colorado       ADAMS
# 199  President/Vice President  Unity Party of Colorado     ALAMOSA
# 200  President/Vice President  Unity Party of Colorado    ARAPAHOE
# 201  President/Vice President  Unity Party of Colorado   ARCHULETA
# 202  President/Vice President  Unity Party of Colorado        BACA
# ..                        ...                      ...         ...
# 259  President/Vice President  Unity Party of Colorado  WASHINGTON
# 260  President/Vice President  Unity Party of Colorado        WELD
# 261  President/Vice President  Unity Party of Colorado        YUMA
# 262  President/Vice President  Unity Party of Colorado         NaN
# 263  President/Vice President  Unity Party of Colorado         NaN
#
#             Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 198              Bill Hammons / Eric Bodenstab                  264
# ...

# %%
upc_total = upc.iloc[[64,65]]
upc_total
# Out:
#           Office/Ballot Issue                    Party County  \
# 262  President/Vice President  Unity Party of Colorado    NaN
# 263  President/Vice President  Unity Party of Colorado    NaN
#
#             Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 262  Bill Hammons / Eric Bodenstab Total Votes                2,730
# 263       Bill Hammons / Eric Bodenstab Vote %                0.08%
#
#     No Votes/Percentage
# 262                 NaN
# 263                 NaN

# %%
upc_clean = upc[0:64]
upc_clean
# Out:
#           Office/Ballot Issue                    Party      County  \
# 198  President/Vice President  Unity Party of Colorado       ADAMS
# 199  President/Vice President  Unity Party of Colorado     ALAMOSA
# 200  President/Vice President  Unity Party of Colorado    ARAPAHOE
# 201  President/Vice President  Unity Party of Colorado   ARCHULETA
# 202  President/Vice President  Unity Party of Colorado        BACA
# ..                        ...                      ...         ...
# 257  President/Vice President  Unity Party of Colorado      SUMMIT
# 258  President/Vice President  Unity Party of Colorado      TELLER
# 259  President/Vice President  Unity Party of Colorado  WASHINGTON
# 260  President/Vice President  Unity Party of Colorado        WELD
# 261  President/Vice President  Unity Party of Colorado        YUMA
#
#     Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 198      Bill Hammons / Eric Bodenstab                  264
# ...

# %%
upc_clean.to_csv('UPCClean.csv')

# %%
green = third_party_pres.loc[third_party_pres['Party'] == 'Green Party']
green
# Out:
#           Office/Ballot Issue        Party      County  \
# 264  President/Vice President  Green Party       ADAMS
# 265  President/Vice President  Green Party     ALAMOSA
# 266  President/Vice President  Green Party    ARAPAHOE
# 267  President/Vice President  Green Party   ARCHULETA
# 268  President/Vice President  Green Party        BACA
# ..                        ...          ...         ...
# 325  President/Vice President  Green Party  WASHINGTON
# 326  President/Vice President  Green Party        WELD
# 327  President/Vice President  Green Party        YUMA
# 328  President/Vice President  Green Party         NaN
# 329  President/Vice President  Green Party         NaN
#
#                    Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 264              Howie Hawkins / Angela Nicole Walker                  744
# 265              Howie Hawkins / Angela Nicole Walker                   23
# 266              Howie Hawkins / Angela Nicole Walker                  926
# ...

# %%
green.to_csv('GreenClean.csv')

# %%
avp = third_party_pres.loc[third_party_pres['Party'] == 'Approval Voting Party']
avp
# Out:
#           Office/Ballot Issue                  Party      County  \
# 330  President/Vice President  Approval Voting Party       ADAMS
# 331  President/Vice President  Approval Voting Party     ALAMOSA
# 332  President/Vice President  Approval Voting Party    ARAPAHOE
# 333  President/Vice President  Approval Voting Party   ARCHULETA
# 334  President/Vice President  Approval Voting Party        BACA
# ..                        ...                    ...         ...
# 391  President/Vice President  Approval Voting Party  WASHINGTON
# 392  President/Vice President  Approval Voting Party        WELD
# 393  President/Vice President  Approval Voting Party        YUMA
# 394  President/Vice President  Approval Voting Party         NaN
# 395  President/Vice President  Approval Voting Party         NaN
#
#          Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 330              Blake Huber / Frank Atwood                   37
# ...

# %%
avp.to_csv("AVPClean.csv")

# %%
lib = third_party_pres.loc[third_party_pres['Party'] == 'Libertarian Party']
lib
# Out:
#           Office/Ballot Issue              Party      County  \
# 396  President/Vice President  Libertarian Party       ADAMS
# 397  President/Vice President  Libertarian Party     ALAMOSA
# 398  President/Vice President  Libertarian Party    ARAPAHOE
# 399  President/Vice President  Libertarian Party   ARCHULETA
# 400  President/Vice President  Libertarian Party        BACA
# ..                        ...                ...         ...
# 457  President/Vice President  Libertarian Party  WASHINGTON
# 458  President/Vice President  Libertarian Party        WELD
# 459  President/Vice President  Libertarian Party        YUMA
# 460  President/Vice President  Libertarian Party         NaN
# 461  President/Vice President  Libertarian Party         NaN
#
#                   Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 396              Jo Jorgensen / Jeremy "Spike" Cohen                3,731
# 397              Jo Jorgensen / Jeremy "Spike" Cohen                   90
# ...

# %%
lib.to_csv('LibClean.csv')

# %% [markdown]
# #### Left off here

# %%
asolp = third_party_pres.loc[third_party_pres['Party'] == 'American Solidarity Party']
asolp
# Out:
#           Office/Ballot Issue                      Party      County  \
# 462  President/Vice President  American Solidarity Party       ADAMS
# 463  President/Vice President  American Solidarity Party     ALAMOSA
# 464  President/Vice President  American Solidarity Party    ARAPAHOE
# 465  President/Vice President  American Solidarity Party   ARCHULETA
# 466  President/Vice President  American Solidarity Party        BACA
# ..                        ...                        ...         ...
# 523  President/Vice President  American Solidarity Party  WASHINGTON
# 524  President/Vice President  American Solidarity Party        WELD
# 525  President/Vice President  American Solidarity Party        YUMA
# 526  President/Vice President  American Solidarity Party         NaN
# 527  President/Vice President  American Solidarity Party         NaN
#
#          Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 462              Brian Carroll / Amar Patel                  160
# ...

# %%
una = third_party_pres.loc[third_party_pres['Party'] == 'Unaffiliated']
una
# Out:
#            Office/Ballot Issue         Party      County  \
# 528   President/Vice President  Unaffiliated       ADAMS
# 529   President/Vice President  Unaffiliated     ALAMOSA
# 530   President/Vice President  Unaffiliated    ARAPAHOE
# 531   President/Vice President  Unaffiliated   ARCHULETA
# 532   President/Vice President  Unaffiliated        BACA
# ...                        ...           ...         ...
# 1381  President/Vice President  Unaffiliated  WASHINGTON
# 1382  President/Vice President  Unaffiliated        WELD
# 1383  President/Vice President  Unaffiliated        YUMA
# 1384  President/Vice President  Unaffiliated         NaN
# 1385  President/Vice President  Unaffiliated         NaN
#
#              Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 528               Mark Charles / Adrian Wallace                  197
# 529               Mark Charles / Adrian Wallace                   11
# 530               Mark Charles / Adrian Wallace                  189
# ...

# %%
proh = third_party_pres.loc[third_party_pres['Party'] == 'Prohibition Party']
proh
# Out:
#           Office/Ballot Issue              Party      County  \
# 594  President/Vice President  Prohibition Party       ADAMS
# 595  President/Vice President  Prohibition Party     ALAMOSA
# 596  President/Vice President  Prohibition Party    ARAPAHOE
# 597  President/Vice President  Prohibition Party   ARCHULETA
# 598  President/Vice President  Prohibition Party        BACA
# ..                        ...                ...         ...
# 655  President/Vice President  Prohibition Party  WASHINGTON
# 656  President/Vice President  Prohibition Party        WELD
# 657  President/Vice President  Prohibition Party        YUMA
# 658  President/Vice President  Prohibition Party         NaN
# 659  President/Vice President  Prohibition Party         NaN
#
#               Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# 594              Phil Collins / Billy Joe Parker                   46
# 595              Phil Collins / Billy Joe Parker                    2
# ...

# %%
allia = third_party_pres.loc[third_party_pres['Party'] == 'Alliance Party']
allia

prog = third_party_pres.loc[third_party_pres['Party'] == 'Progressive Party']
prog

socw = third_party_pres.loc[third_party_pres['Party'] == 'Socialist Workers Party']
socw

soce = third_party_pres.loc[third_party_pres['Party'] == 'Socialist Equality Party']
soce

iap = third_party_pres.loc[third_party_pres['Party'] == 'Independent American Party']
iap

socl = third_party_pres.loc[third_party_pres['Party'] == 'Socialism and Liberation']
socl

npa = third_party_pres.loc[third_party_pres['Party'] == 'No Party Affiliation']
npa

ind = third_party_pres.loc[third_party_pres['Party'] == 'Independent']
ind

unanp = third_party_pres.loc[third_party_pres['Party'] == 'Unaffiliated / No Party Affiliation']
unanp
# Out:
#            Office/Ballot Issue                                Party  \
# 1518  President/Vice President  Unaffiliated / No Party Affiliation
# 1519  President/Vice President  Unaffiliated / No Party Affiliation
# 1520  President/Vice President  Unaffiliated / No Party Affiliation
# 1521  President/Vice President  Unaffiliated / No Party Affiliation
# 1522  President/Vice President  Unaffiliated / No Party Affiliation
# ...                        ...                                  ...
# 1579  President/Vice President  Unaffiliated / No Party Affiliation
# 1580  President/Vice President  Unaffiliated / No Party Affiliation
# 1581  President/Vice President  Unaffiliated / No Party Affiliation
# 1582  President/Vice President  Unaffiliated / No Party Affiliation
# 1583  President/Vice President  Unaffiliated / No Party Affiliation
#
#           County     Candidate/Judge/Ballot Issue Title Yes Votes/Percentage  \
# ...

# %%
frames = [acp, upc, green, avp, lib, asolp, una, proh, allia, prog, socw, soce, iap, socl, npa, ind, unanp]

# %%
acp['County'].unique()
# Out:
# array(['ADAMS', 'ALAMOSA', 'ARAPAHOE', 'ARCHULETA', 'BACA', 'BENT',
#        'BOULDER', 'BROOMFIELD', 'CHAFFEE', 'CHEYENNE', 'CLEAR CREEK',
#        'CONEJOS', 'COSTILLA', 'CROWLEY', 'CUSTER', 'DELTA', 'DENVER',
#        'DOLORES', 'DOUGLAS', 'EAGLE', 'ELBERT', 'EL PASO', 'FREMONT',
#        'GARFIELD', 'GILPIN', 'GRAND', 'GUNNISON', 'HINSDALE', 'HUERFANO',
#        'JACKSON', 'JEFFERSON', 'KIOWA', 'KIT CARSON', 'LAKE', 'LA PLATA',
#        'LARIMER', 'LAS ANIMAS', 'LINCOLN', 'LOGAN', 'MESA', 'MINERAL',
#        'MOFFAT', 'MONTEZUMA', 'MONTROSE', 'MORGAN', 'OTERO', 'OURAY',
#        'PARK', 'PHILLIPS', 'PITKIN', 'PROWERS', 'PUEBLO', 'RIO BLANCO',
#        'RIO GRANDE', 'ROUTT', 'SAGUACHE', 'SAN JUAN', 'SAN MIGUEL',
#        'SEDGWICK', 'SUMMIT', 'TELLER', 'WASHINGTON', 'WELD', 'YUMA', nan],
#       dtype=object)

# %%
counties = ['ADAMS', 'ALAMOSA', 'ARAPAHOE', 'ARCHULETA', 'BACA', 'BENT',
       'BOULDER', 'BROOMFIELD', 'CHAFFEE', 'CHEYENNE', 'CLEAR CREEK',
       'CONEJOS', 'COSTILLA', 'CROWLEY', 'CUSTER', 'DELTA', 'DENVER',
       'DOLORES', 'DOUGLAS', 'EAGLE', 'ELBERT', 'EL PASO', 'FREMONT',
       'GARFIELD', 'GILPIN', 'GRAND', 'GUNNISON', 'HINSDALE', 'HUERFANO',
       'JACKSON', 'JEFFERSON', 'KIOWA', 'KIT CARSON', 'LAKE', 'LA PLATA',
       'LARIMER', 'LAS ANIMAS', 'LINCOLN', 'LOGAN', 'MESA', 'MINERAL',
       'MOFFAT', 'MONTEZUMA', 'MONTROSE', 'MORGAN', 'OTERO', 'OURAY',
       'PARK', 'PHILLIPS', 'PITKIN', 'PROWERS', 'PUEBLO', 'RIO BLANCO',
       'RIO GRANDE', 'ROUTT', 'SAGUACHE', 'SAN JUAN', 'SAN MIGUEL',
       'SEDGWICK', 'SUMMIT', 'TELLER', 'WASHINGTON', 'WELD', 'YUMA']

# %%
result = pd.concat(frames, keys=counties)
result
# Out:
#                   Office/Ballot Issue                                Party  \
# ADAMS  132   President/Vice President          American Constitution Party
#        133   President/Vice President          American Constitution Party
#        134   President/Vice President          American Constitution Party
#        135   President/Vice President          American Constitution Party
#        136   President/Vice President          American Constitution Party
# ...                               ...                                  ...
# DENVER 1579  President/Vice President  Unaffiliated / No Party Affiliation
#        1580  President/Vice President  Unaffiliated / No Party Affiliation
#        1581  President/Vice President  Unaffiliated / No Party Affiliation
#        1582  President/Vice President  Unaffiliated / No Party Affiliation
#        1583  President/Vice President  Unaffiliated / No Party Affiliation
#
#                  County     Candidate/Judge/Ballot Issue Title  \
# ...
